# %%
import pandas as pd
from io import StringIO

# %%
import datetime

# %%
import bz2

# %%
columns=['video_id','comment_id','likes','code',
         'source_user_id','target_user_id', 
         'comment']

# %%
new_columns=['video_id','comment_id','likes','code',
         'source_user_id','target_user_id',
         'parent_comment_id','depth','comment']

# %%
def dict_to_string(dictionary, columns):
    string = ''
    for c in columns:
        string += str(dictionary[c])
        string += ','
    string += '\n'
    return string

# %%
def combine_comment_segments(comment_segments):
    comment = ''
    for seg in comment_segments:
        comment += seg
    return comment

# %%
try: 
    print('time start: {0}'.format(datetime.datetime.now()))
    with bz2.open('./user_convos_2.bz2', 'at') as fout:
        with bz2.BZ2File('./user_comments.csv.bz2', 'r') as fin:
            i = 0

            # For each user, their latest comment id
            latest_comment = {}
            # For each user, their latest comment's depth
            latest_depth = {}
            for line in fin:
                
                # Debugging
                #i += 1
                #if i == 100: 
                #    break

                line = line.decode('utf-8')
                line = line.rstrip()
                ls = line.split(",")

                # Concatenate comments into one column (previously separated at each comma)
                comment = combine_comment_segments(
                    ls[len(columns)-1: len(ls)]
                )
                data = ls[0:len(columns)-1]
                data.append(comment)


                data_dict = dict(zip(columns, data))

                code = int(data_dict['code'])
                comment_id = data_dict['comment_id']
                source_user_id = data_dict['source_user_id']

                if code == 0:
                    parent_comment_id = 'root'
                    depth = 0
                    # Reset to a dictionary with just the (new) root comment
                    latest_comment = {source_user_id: comment_id}
                    latest_depth = {source_user_id: 0}

                # User source_id replies to user target_id, and target_id exists in thread
                # We assume that source_id is replying to target_id's *latest* comment
                # code == 3 is a special case where target comment == root comment 
                #    (thus, target_id == root comment user)
                elif code == 1 or code == 3:
                    target_user_id = data_dict['target_user_id']
                    if target_user_id in latest_comment.keys():
                        parent_comment_id = latest_comment[target_user_id]
                        depth = latest_depth[target_user_id]+1
                        latest_comment[source_user_id] = comment_id
                        latest_depth[source_user_id] = depth
                
                # Ways to deal with code==2 (target user not existent so far in the thread) or REMOVED_USER:
                #   - Treat as depth 1, replying to root
                #   - Treat as depth 1, replying to non-existent parent (parent_comment_id = -1)
                #   [x] - Ignore (i.e. don't write), and ignore future replies to this comment
                # Thus if we've arrived at any of these else statements, then the comment is either:
                #   (1) target_id == REMOVED_USER (and code == 1)
                #   (2) code == 2
                #   (3) a reply to one of the above without a "sensible" comment by target_id occuring in between
                    else:
                        parent_comment_id = '-1'
                        depth = '-1'         
                else:
                    # Code == 2
                    parent_comment_id = '-1'
                    depth = '-1'

                data_dict['parent_comment_id'] = parent_comment_id
                data_dict['depth'] = depth

                #print(data_dict)
                #print('code: {0}, comment_id: {1}'.format(code, comment_id))
                #print()

                fout.write(dict_to_string(data_dict, new_columns))
                
except:
    print('iteration: {0}'.format(i))
    print('data_dict: {0}'.format(data_dict))
    print('latest_comment: {0}'.format(latest_comment))
    print('latest_depth: {0}'.format(latest_depth))
    raise

finally:
    print('time end: {0}'.format(datetime.datetime.now()))
# Out:
# time start: 2022-07-05 17:57:31.907371
# time end: 2022-07-05 19:02:05.251984

# %%
# Time ~ 1hr

# %%
# Find a suitable example tree
tree = []
desired_depth = 10

with bz2.BZ2File('./user_convos_2.bz2', 'r') as fin:
    max_depth = 0
    i = 0
    for line in fin:
        # i += 1
        # if i == 100: 
        #     break
        
        line = line.decode('utf-8')
        line = line.rstrip()
        ls = line.split(",")
        
        data = dict(zip(new_columns, ls))
        
        code = int(data['code'])
        depth = int(data['depth'])
        
        # print('depth: {0}, max_depth: {1}'.format(depth, max_depth))
        
        if depth > max_depth:
            max_depth = depth
        
        if code==0:
            if max_depth > desired_depth:
                break
            else:
                # new thread
                tree = []
                max_depth = 0
            
        tree.append(data)  
        
        # print(data)

# %%
# Has desired depth
tree
# Out:
# [{'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'likes': '197',
#   'code': '0',
#   'source_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'target_user_id': 'L',
#   'parent_comment_id': 'root',
#   'depth': '0',
#   'comment': 'Trump Barr and his various enablers are discusting.'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArY2lYA5US',
#   'likes': '6',
#   'code': '3',
#   'source_user_id': 'UC8B_-1i9J2ujmf6SngxPHOQ',
#   'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'depth': '1',
#   'comment': 'So is your English. Are you new to this country? Welcome to America!'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArYa6AyI2S',
#   'likes': '29',
#   'code': '1',
#   'source_user_id': 'UCOrva2qlW7Cd-hnLXe1zM8Q',
#   'target_user_id': 'UC8B_-1i9J2ujmf6SngxPHOQ',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArY2lYA5US',
#   'depth': '2',
#   'comment': "...Don't act like you like newcomers to America. Let me correct his typo... You are disgusting!"},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArbDycXnIW',
#   'likes': '6',
#   'code': '1',
#   'source_user_id': 'UC6XYtbhkSmjF16EW7_UWd9w',
#   'target_user_id': 'UC8B_-1i9J2ujmf6SngxPHOQ',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArY2lYA5US',
#   'depth': '2',
#   'comment': 'Maybe we should disgust this on another thread. 😆'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arf_jxQmlc',
#   'likes': '13',
#   'code': '1',
#   'source_user_id': 'UCXmyXOJCRuR8fRsZnW5f2BA',
#   'target_user_id': 'UC8B_-1i9J2ujmf6SngxPHOQ',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArY2lYA5US',
#   'depth': '2',
#   'comment': "you're replying on an international website like YouTube he probably speaks more languages than you"},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9AriTJdZrQG',
#   'likes': '5',
#   'code': '1',
#   'source_user_id': 'UCu4TSEk1OW9PzVML4euL3nw',
#   'target_user_id': 'UC8B_-1i9J2ujmf6SngxPHOQ',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArY2lYA5US',
#   'depth': '2',
#   'comment': '<<— you’re still a Fake Page Idiot Trolling. 🚨'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arm1kPOc1d',
#   'likes': '2',
#   'code': '1',
#   'source_user_id': 'UC0YRikvXBWzscHbPxJCTaQQ',
#   'target_user_id': 'UCXmyXOJCRuR8fRsZnW5f2BA',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arf_jxQmlc',
#   'depth': '3',
#   'comment': "ost likely! Didn't Trump say that he likes the uneducated?"},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArnoLgNMW4',
#   'likes': '0',
#   'code': '3',
#   'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'depth': '1',
#   'comment': 'charges should be brought against him'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Aro_5tyjVD',
#   'likes': '0',
#   'code': '3',
#   'source_user_id': 'UCj_km_BXSry8zqJP0Z6upcQ',
#   'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'depth': '1',
#   'comment': 'Losing Micheal Flynn to false witch hunts was OK though?'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArotQy5gth',
#   'likes': '4',
#   'code': '1',
#   'source_user_id': 'UCQC1ZxoKwZHqkWylJLXF0Lw',
#   'target_user_id': 'UCj_km_BXSry8zqJP0Z6upcQ',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Aro_5tyjVD',
#   'depth': '2',
#   'comment': 'what false witch hunts? Michael Flynn was found guilty of lying and not complying with investigations.'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arp5jAMsyX',
#   'likes': '1',
#   'code': '3',
#   'source_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#   'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'depth': '1',
#   'comment': 'Try DISGUSTED... DISGUSTING...DIS...GUST'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArpLndIWhh',
#   'likes': '1',
#   'code': '1',
#   'source_user_id': 'UCVIk_U_sGW0cm2td64MOQhQ',
#   'target_user_id': 'UCj_km_BXSry8zqJP0Z6upcQ',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Aro_5tyjVD',
#   'depth': '2',
#   'comment': 'LEAD GUILTY to lying to the FBI about talking to Russia and lobbying Turkey. It’s only a hoax if it didn’t happen!'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArpkhGwc60',
#   'likes': '1',
#   'code': '1',
#   'source_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#   'target_user_id': 'UCVIk_U_sGW0cm2td64MOQhQ',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArpLndIWhh',
#   'depth': '3',
#   'comment': "f it didn't happen why did he plead guilty? You make no sense. They had tons of evidence enough for him to turn state's witness until Trump underlined the justice system so badly he thought he could get away with his crimes and changed his plea."},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArplYVceoU',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'target_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arp5jAMsyX',
#   'depth': '2',
#   'comment': 'What’s a disgusting he was blackballed he was forced to resign'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arpqx7re2O',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'target_user_id': 'UCj_km_BXSry8zqJP0Z6upcQ',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Aro_5tyjVD',
#   'depth': '2',
#   'comment': 'Well that’s the usual double standard the thing with today’s these leftists have expose themselves and their methodology is open for everyone to see it’s so predictable'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arq1qMAbLh',
#   'likes': '1',
#   'code': '3',
#   'source_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#   'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'depth': '1',
#   'comment': 'And Vindman was Russian.'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arq6fRW-_O',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#   'target_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arpqx7re2O',
#   'depth': '3',
#   'comment': 'He was a traitor to the 🇺🇸'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArqBw0VvQd',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'target_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arq6fRW-_O',
#   'depth': '4',
#   'comment': 'was he?'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArqED-7gAY',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#   'target_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArqBw0VvQd',
#   'depth': '5',
#   'comment': 'hahaha "you leftists "? You mean American patriots who respect heros?'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arqn3jIgso',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'target_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArqED-7gAY',
#   'depth': '6',
#   'comment': 'I mean leftists.and what’s with hero nonsense what are you 10 years old'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arr6Halgn2',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#   'target_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arqn3jIgso',
#   'depth': '7',
#   'comment': "He was. His Parents were Russian and he was a traitor. The left continues to try and tear America apart. AOC said in a tweet. Lets keep the economy down so Trump won't get re-elected. All Democratic city mayors willing to let their cities burn to harm Trump. Defund the police??? Yeah. Lets see how that went.. oh yeah crime up 600 percent in some cities. Nice job Dems. Rioters protesting and shutting down highways. All to harm Trump. BLM??? Sure they do as long as its a cop that harms them yet 205 unarmed whites 104 unarmed blacks were harmed by police. For some reason I'm not allowed to say k . Ill..ed I get deleted everytime."},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArrxPX44Vy',
#   'likes': '0',
#   'code': '3',
#   'source_user_id': 'UCoOJg6dZZvzCEeFUj7ECQCg',
#   'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'depth': '1',
#   'comment': 'Ltc "Oh say can you seeeee.." Vindman\'s loyalty is to Ukraine and the Deep State. His uniform was looking a little tight anyway..🐷'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArryYA0mjo',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'target_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arr6Halgn2',
#   'depth': '8',
#   'comment': 'You know this will completely backfire on them their way out of their element'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Ars7V8fPsh',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCBG72GDHC-_NyD1H48PeEzQ',
#   'target_user_id': 'UCOrva2qlW7Cd-hnLXe1zM8Q',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArYa6AyI2S',
#   'depth': '3',
#   'comment': "you're a bit disgusting"},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArsA01_gbF',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#   'target_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArryYA0mjo',
#   'depth': '9',
#   'comment': 'no but ypu act like you are. The Rethuglicans have failed the America people so badly they will lose power for a generation or more. You have tobcreate a fantasy narrative so you can keep being aggrieved that the world is changing.'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArsBO1ZR74',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCBG72GDHC-_NyD1H48PeEzQ',
#   'target_user_id': 'REMOVED_USER',
#   'parent_comment_id': '-1',
#   'depth': '-1',
#   'comment': 'discussed?'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArsQy-Vma4',
#   'likes': '0',
#   'code': '3',
#   'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'depth': '1',
#   'comment': 'YouRuse is A leftist org how so?'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Art6LIcAUT',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCj_km_BXSry8zqJP0Z6upcQ',
#   'target_user_id': 'UCQC1ZxoKwZHqkWylJLXF0Lw',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArotQy5gth',
#   'depth': '3',
#   'comment': 'LOL We all know what the truth is about that fiasco!'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Art_FNDeWI',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCVIk_U_sGW0cm2td64MOQhQ',
#   'target_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArsA01_gbF',
#   'depth': '10',
#   'comment': "what are you talking about? I'm saying Flynn is obviously guilty"},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArtbUd3Ur3',
#   'likes': '1',
#   'code': '3',
#   'source_user_id': 'UC4HfVvXR_dkOf78TFoXE_hQ',
#   'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'depth': '1',
#   'comment': 'use spell check mate'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArtmXeagYR',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#   'target_user_id': 'UCVIk_U_sGW0cm2td64MOQhQ',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Art_FNDeWI',
#   'depth': '11',
#   'comment': 'h sorry. I misunderstood. My bad.'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArufnHtMkf',
#   'likes': '1',
#   'code': '1',
#   'source_user_id': 'UCVIk_U_sGW0cm2td64MOQhQ',
#   'target_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArtmXeagYR',
#   'depth': '12',
#   'comment': '😁🙋\u200d♂️'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArujEImXLj',
#   'likes': '0',
#   'code': '3',
#   'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'depth': '1',
#   'comment': 'Don’t believe everything they taught you in college they bullshitted you'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Aruy6zmNBN',
#   'likes': '0',
#   'code': '3',
#   'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#   'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'depth': '1',
#   'comment': 'When I say money talks but I really mean profits talk what people say one or feel simply doesn’t matter'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9AryFr9xYio',
#   'likes': '1',
#   'code': '3',
#   'source_user_id': 'UC5bMZbJoeuFxO5mmf4IQ8LA',
#   'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#   'depth': '1',
#   'comment': 'Trump is dumb putz forever.'},
#  {'video_id': 'uu6rQCDn_DE',
#   'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Asbcv_ioSj',
#   'likes': '0',
#   'code': '1',
#   'source_user_id': 'UC_xllRzvObmxI8VynYBwrzQ',
#   'target_user_id': 'UCXmyXOJCRuR8fRsZnW5f2BA',
#   'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arf_jxQmlc',
#   'depth': '3',
#   'comment': 'but how many does he speak correctly because so far English isnt one of them'}]

# %%
len(tree)
# Out:
# 36

# %%
# source: https://www.geeksforgeeks.org/how-to-get-value-from-address-in-python/
import ctypes
def get_address(obj):
    return id(obj)
# e.g. 140650723644544
def get_obj(address):
    return ctypes.cast(address, ctypes.py_object).value

# %%
import copy
tree_copy = copy.deepcopy(tree)

# %%
# make the json tree
tree_copy[0]['children']=[]
tree_json = tree_copy[0]
# comment_id --> reference to the childrens list of the comment ID
children_ref = {}
children_ref[tree_copy[0]['comment_id']] = get_address(tree_copy[0]['children'])

for node in tree_copy[1:]:
    # Ignore if one of the (1-3) edge cases described above
    if node['parent_comment_id'] not in children_ref.keys():
        continue
    if len(node['comment']) > 10:
        node['comment'] = node['comment'][:10] + '...'
    node['children'] = []

    attach_list_ref = children_ref[node['parent_comment_id']]
    attach_list = get_obj(attach_list_ref)
    attach_list.append(node)
    
    children_ref[node['comment_id']] = get_address(node['children'])

# %%
tree_json
# Out:
# {'video_id': 'uu6rQCDn_DE',
#  'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#  'likes': '197',
#  'code': '0',
#  'source_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#  'target_user_id': 'L',
#  'parent_comment_id': 'root',
#  'depth': '0',
#  'comment': 'Trump Barr and his various enablers are discusting.',
#  'children': [{'video_id': 'uu6rQCDn_DE',
#    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArY2lYA5US',
#    'likes': '6',
#    'code': '3',
#    'source_user_id': 'UC8B_-1i9J2ujmf6SngxPHOQ',
#    'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#    'depth': '1',
#    'comment': 'So is your...',
#    'children': [{'video_id': 'uu6rQCDn_DE',
#      'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArYa6AyI2S',
#      'likes': '29',
#      'code': '1',
#      'source_user_id': 'UCOrva2qlW7Cd-hnLXe1zM8Q',
#      'target_user_id': 'UC8B_-1i9J2ujmf6SngxPHOQ',
#      'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArY2lYA5US',
#      'depth': '2',
#      'comment': "...Don't a...",
#      'children': [{'video_id': 'uu6rQCDn_DE',
#        'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Ars7V8fPsh',
#        'likes': '0',
#        'code': '1',
#        'source_user_id': 'UCBG72GDHC-_NyD1H48PeEzQ',
#        'target_user_id': 'UCOrva2qlW7Cd-hnLXe1zM8Q',
#        'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArYa6AyI2S',
#        'depth': '3',
#        'comment': "you're a b...",
#        'children': []}]},
#     {'video_id': 'uu6rQCDn_DE',
#      'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArbDycXnIW',
#      'likes': '6',
#      'code': '1',
#      'source_user_id': 'UC6XYtbhkSmjF16EW7_UWd9w',
#      'target_user_id': 'UC8B_-1i9J2ujmf6SngxPHOQ',
#      'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArY2lYA5US',
#      'depth': '2',
#      'comment': 'Maybe we s...',
#      'children': []},
#     {'video_id': 'uu6rQCDn_DE',
#      'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arf_jxQmlc',
#      'likes': '13',
#      'code': '1',
#      'source_user_id': 'UCXmyXOJCRuR8fRsZnW5f2BA',
#      'target_user_id': 'UC8B_-1i9J2ujmf6SngxPHOQ',
#      'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArY2lYA5US',
#      'depth': '2',
#      'comment': "you're rep...",
#      'children': [{'video_id': 'uu6rQCDn_DE',
#        'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arm1kPOc1d',
#        'likes': '2',
#        'code': '1',
#        'source_user_id': 'UC0YRikvXBWzscHbPxJCTaQQ',
#        'target_user_id': 'UCXmyXOJCRuR8fRsZnW5f2BA',
#        'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arf_jxQmlc',
#        'depth': '3',
#        'comment': 'ost likely...',
#        'children': []},
#       {'video_id': 'uu6rQCDn_DE',
#        'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Asbcv_ioSj',
#        'likes': '0',
#        'code': '1',
#        'source_user_id': 'UC_xllRzvObmxI8VynYBwrzQ',
#        'target_user_id': 'UCXmyXOJCRuR8fRsZnW5f2BA',
#        'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arf_jxQmlc',
#        'depth': '3',
#        'comment': 'but how ma...',
#        'children': []}]},
#     {'video_id': 'uu6rQCDn_DE',
#      'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9AriTJdZrQG',
#      'likes': '5',
#      'code': '1',
#      'source_user_id': 'UCu4TSEk1OW9PzVML4euL3nw',
#      'target_user_id': 'UC8B_-1i9J2ujmf6SngxPHOQ',
#      'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArY2lYA5US',
#      'depth': '2',
#      'comment': '<<— you’re...',
#      'children': []}]},
#   {'video_id': 'uu6rQCDn_DE',
#    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArnoLgNMW4',
#    'likes': '0',
#    'code': '3',
#    'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#    'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#    'depth': '1',
#    'comment': 'charges sh...',
#    'children': []},
#   {'video_id': 'uu6rQCDn_DE',
#    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Aro_5tyjVD',
#    'likes': '0',
#    'code': '3',
#    'source_user_id': 'UCj_km_BXSry8zqJP0Z6upcQ',
#    'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#    'depth': '1',
#    'comment': 'Losing Mic...',
#    'children': [{'video_id': 'uu6rQCDn_DE',
#      'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArotQy5gth',
#      'likes': '4',
#      'code': '1',
#      'source_user_id': 'UCQC1ZxoKwZHqkWylJLXF0Lw',
#      'target_user_id': 'UCj_km_BXSry8zqJP0Z6upcQ',
#      'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Aro_5tyjVD',
#      'depth': '2',
#      'comment': 'what false...',
#      'children': [{'video_id': 'uu6rQCDn_DE',
#        'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Art6LIcAUT',
#        'likes': '0',
#        'code': '1',
#        'source_user_id': 'UCj_km_BXSry8zqJP0Z6upcQ',
#        'target_user_id': 'UCQC1ZxoKwZHqkWylJLXF0Lw',
#        'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArotQy5gth',
#        'depth': '3',
#        'comment': 'LOL We all...',
#        'children': []}]},
#     {'video_id': 'uu6rQCDn_DE',
#      'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArpLndIWhh',
#      'likes': '1',
#      'code': '1',
#      'source_user_id': 'UCVIk_U_sGW0cm2td64MOQhQ',
#      'target_user_id': 'UCj_km_BXSry8zqJP0Z6upcQ',
#      'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Aro_5tyjVD',
#      'depth': '2',
#      'comment': 'LEAD GUILT...',
#      'children': [{'video_id': 'uu6rQCDn_DE',
#        'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArpkhGwc60',
#        'likes': '1',
#        'code': '1',
#        'source_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#        'target_user_id': 'UCVIk_U_sGW0cm2td64MOQhQ',
#        'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArpLndIWhh',
#        'depth': '3',
#        'comment': "f it didn'...",
#        'children': []}]},
#     {'video_id': 'uu6rQCDn_DE',
#      'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arpqx7re2O',
#      'likes': '0',
#      'code': '1',
#      'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#      'target_user_id': 'UCj_km_BXSry8zqJP0Z6upcQ',
#      'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Aro_5tyjVD',
#      'depth': '2',
#      'comment': 'Well that’...',
#      'children': [{'video_id': 'uu6rQCDn_DE',
#        'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arq6fRW-_O',
#        'likes': '0',
#        'code': '1',
#        'source_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#        'target_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#        'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arpqx7re2O',
#        'depth': '3',
#        'comment': 'He was a t...',
#        'children': [{'video_id': 'uu6rQCDn_DE',
#          'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArqBw0VvQd',
#          'likes': '0',
#          'code': '1',
#          'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#          'target_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#          'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arq6fRW-_O',
#          'depth': '4',
#          'comment': 'was he?',
#          'children': [{'video_id': 'uu6rQCDn_DE',
#            'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArqED-7gAY',
#            'likes': '0',
#            'code': '1',
#            'source_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#            'target_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#            'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArqBw0VvQd',
#            'depth': '5',
#            'comment': 'hahaha "yo...',
#            'children': [{'video_id': 'uu6rQCDn_DE',
#              'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arqn3jIgso',
#              'likes': '0',
#              'code': '1',
#              'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#              'target_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#              'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArqED-7gAY',
#              'depth': '6',
#              'comment': 'I mean lef...',
#              'children': [{'video_id': 'uu6rQCDn_DE',
#                'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arr6Halgn2',
#                'likes': '0',
#                'code': '1',
#                'source_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#                'target_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#                'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arqn3jIgso',
#                'depth': '7',
#                'comment': 'He was. Hi...',
#                'children': [{'video_id': 'uu6rQCDn_DE',
#                  'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArryYA0mjo',
#                  'likes': '0',
#                  'code': '1',
#                  'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#                  'target_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#                  'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arr6Halgn2',
#                  'depth': '8',
#                  'comment': 'You know t...',
#                  'children': [{'video_id': 'uu6rQCDn_DE',
#                    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArsA01_gbF',
#                    'likes': '0',
#                    'code': '1',
#                    'source_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#                    'target_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#                    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArryYA0mjo',
#                    'depth': '9',
#                    'comment': 'no but ypu...',
#                    'children': [{'video_id': 'uu6rQCDn_DE',
#                      'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Art_FNDeWI',
#                      'likes': '0',
#                      'code': '1',
#                      'source_user_id': 'UCVIk_U_sGW0cm2td64MOQhQ',
#                      'target_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#                      'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArsA01_gbF',
#                      'depth': '10',
#                      'comment': 'what are y...',
#                      'children': [{'video_id': 'uu6rQCDn_DE',
#                        'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArtmXeagYR',
#                        'likes': '0',
#                        'code': '1',
#                        'source_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#                        'target_user_id': 'UCVIk_U_sGW0cm2td64MOQhQ',
#                        'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Art_FNDeWI',
#                        'depth': '11',
#                        'comment': 'h sorry. I...',
#                        'children': [{'video_id': 'uu6rQCDn_DE',
#                          'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArufnHtMkf',
#                          'likes': '1',
#                          'code': '1',
#                          'source_user_id': 'UCVIk_U_sGW0cm2td64MOQhQ',
#                          'target_user_id': 'UCbZU0P_Cqbel44KJOIc3r-A',
#                          'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArtmXeagYR',
#                          'depth': '12',
#                          'comment': '😁🙋\u200d♂️',
#                          'children': []}]}]}]}]}]}]}]}]}]}]}]},
#   {'video_id': 'uu6rQCDn_DE',
#    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arp5jAMsyX',
#    'likes': '1',
#    'code': '3',
#    'source_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#    'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#    'depth': '1',
#    'comment': 'Try DISGUS...',
#    'children': [{'video_id': 'uu6rQCDn_DE',
#      'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArplYVceoU',
#      'likes': '0',
#      'code': '1',
#      'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#      'target_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#      'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arp5jAMsyX',
#      'depth': '2',
#      'comment': 'What’s a d...',
#      'children': []}]},
#   {'video_id': 'uu6rQCDn_DE',
#    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Arq1qMAbLh',
#    'likes': '1',
#    'code': '3',
#    'source_user_id': 'UC-CXJ9byX-1VUwJCqjsRHtg',
#    'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#    'depth': '1',
#    'comment': 'And Vindma...',
#    'children': []},
#   {'video_id': 'uu6rQCDn_DE',
#    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArrxPX44Vy',
#    'likes': '0',
#    'code': '3',
#    'source_user_id': 'UCoOJg6dZZvzCEeFUj7ECQCg',
#    'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#    'depth': '1',
#    'comment': 'Ltc "Oh sa...',
#    'children': []},
#   {'video_id': 'uu6rQCDn_DE',
#    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArsQy-Vma4',
#    'likes': '0',
#    'code': '3',
#    'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#    'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#    'depth': '1',
#    'comment': 'YouRuse is...',
#    'children': []},
#   {'video_id': 'uu6rQCDn_DE',
#    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArtbUd3Ur3',
#    'likes': '1',
#    'code': '3',
#    'source_user_id': 'UC4HfVvXR_dkOf78TFoXE_hQ',
#    'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#    'depth': '1',
#    'comment': 'use spell ...',
#    'children': []},
#   {'video_id': 'uu6rQCDn_DE',
#    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9ArujEImXLj',
#    'likes': '0',
#    'code': '3',
#    'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#    'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#    'depth': '1',
#    'comment': 'Don’t beli...',
#    'children': []},
#   {'video_id': 'uu6rQCDn_DE',
#    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9Aruy6zmNBN',
#    'likes': '0',
#    'code': '3',
#    'source_user_id': 'UCvvssN3D5-YUFKMWdcdJs4g',
#    'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#    'depth': '1',
#    'comment': 'When I say...',
#    'children': []},
#   {'video_id': 'uu6rQCDn_DE',
#    'comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg.9ArTs3ZsaXO9AryFr9xYio',
#    'likes': '1',
#    'code': '3',
#    'source_user_id': 'UC5bMZbJoeuFxO5mmf4IQ8LA',
#    'target_user_id': 'UCfEbMejPZjYoJuHRUCnejAg',
#    'parent_comment_id': 'UgzxbaDCpzIVRYvjIiB4AaABAg',
#    'depth': '1',
#    'comment': 'Trump is d...',
#    'children': []}]}

# %%
import json
with open("example_tree_2.json", "w") as out:
    json.dump(tree_json, out)
